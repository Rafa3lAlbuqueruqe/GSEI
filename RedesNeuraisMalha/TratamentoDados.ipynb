# %%
import glob
import pandas as pd

# %%
SaidasRede = pd.read_csv('Dados/localização dos defeitos em metros.txt', skiprows=3, sep=r'\s+', header= None)
SaidasRede = SaidasRede.iloc[:,1:3]
caminho = 'Dados/harmonicas'
padrao = caminho + '/*.dat'

# %%
arquivos = glob.glob(padrao)

# %%
dff = pd.read_csv(arquivos[0], dtype=float , header=None)

# %%
df = pd.DataFrame()

# %%
for i , arquivo in enumerate(arquivos):
    df[f'{i}'] = pd.read_csv(arquivo, dtype=float , header=None).iloc[:, 0]

# %%
df
# Out:
#             0         1         2         3             4         5         6  \
# 0    0.000007  0.000008  0.000006  0.000007  5.311329e-06  0.000008  0.000008
# 1    0.000006  0.000007  0.000005  0.000006  3.661984e-06  0.000007  0.000006
# 2    0.000005  0.000005  0.000003  0.000005  1.972429e-06  0.000005  0.000004
# 3    0.000004  0.000003  0.000003  0.000004  6.180459e-07  0.000004  0.000002
# 4    0.000003  0.000002  0.000003  0.000004  1.228799e-06  0.000003  0.000001
# ..        ...       ...       ...       ...           ...       ...       ...
# 161  0.000002  0.000002  0.000003  0.000002  2.153806e-06  0.000003  0.000003
# 162  0.000002  0.000002  0.000003  0.000002  1.815543e-06  0.000002  0.000003
# 163  0.000001  0.000001  0.000002  0.000001  1.331504e-06  0.000002  0.000002
# 164  0.000002  0.000002  0.000002  0.000002  1.753184e-06  0.000002  0.000002
# 165  0.000002  0.000002  0.000001  0.000002  1.777043e-06  0.000002  0.000001
#
# ...

# %%
df = df.T

# %%
df
# Out:
#          0         1         2             3         4         5         6    \
# 0   0.000007  0.000006  0.000005  3.787368e-06  0.000003  0.000004  0.000007
# 1   0.000008  0.000007  0.000005  2.647402e-06  0.000002  0.000005  0.000008
# 2   0.000006  0.000005  0.000003  2.515174e-06  0.000003  0.000005  0.000007
# 3   0.000007  0.000006  0.000005  3.932294e-06  0.000004  0.000005  0.000007
# 4   0.000005  0.000004  0.000002  6.180459e-07  0.000001  0.000004  0.000006
# 5   0.000008  0.000007  0.000005  4.138264e-06  0.000003  0.000004  0.000006
# 6   0.000008  0.000006  0.000004  2.023168e-06  0.000001  0.000004  0.000007
# 7   0.000007  0.000007  0.000005  4.063209e-06  0.000004  0.000005  0.000007
# 8   0.000005  0.000005  0.000006  5.797097e-06  0.000006  0.000007  0.000007
# 9   0.000007  0.000006  0.000005  3.496085e-06  0.000003  0.000005  0.000007
# 10  0.000008  0.000007  0.000005  3.985006e-06  0.000003  0.000004  0.000007
# ...

# %%
# def normali(df): return (df - df.min()) / (df.max() - df.min())
# df = normali(df)

# %%
def normali(df):
    max_valor = df.max().max()  # Maior valor no DataFrame inteiro
    return df / max_valor 
df = normali(df)

# %%
df
# Out:
#          0         1         2         3         4         5         6    \
# 0   0.611442  0.533114  0.418964  0.314236  0.263887  0.368821  0.547268
# 1   0.672783  0.554483  0.387189  0.219653  0.179703  0.409712  0.644701
# 2   0.495545  0.400663  0.288956  0.208683  0.225260  0.377984  0.562053
# 3   0.595291  0.507557  0.403211  0.326260  0.313064  0.413994  0.568027
# 4   0.440678  0.303833  0.163651  0.051279  0.101953  0.295839  0.484548
# 5   0.631630  0.561813  0.451720  0.343349  0.268114  0.330860  0.493749
# 6   0.663312  0.533595  0.352349  0.167861  0.119640  0.363042  0.606762
# 7   0.617337  0.548532  0.442748  0.337122  0.295509  0.402650  0.568628
# 8   0.423728  0.444751  0.461831  0.480982  0.510144  0.542518  0.576879
# 9   0.591511  0.503961  0.388128  0.290068  0.262532  0.389879  0.575156
# 10  0.629024  0.552216  0.437869  0.330634  0.274908  0.370839  0.547918
# 11  0.788070  0.732495  0.608773  0.483678  0.421335  0.528689  0.739397
# ...

# %%
df.to_parquet('X.parquet')

# %%
SaidasRede.to_parquet('Y.parquet')
