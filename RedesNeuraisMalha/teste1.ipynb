# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Input
import pandas as pd
import io
import os
import requests
import numpy as np
from sklearn import metrics

# %%
df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/auto-mpg.csv", 
    na_values=['NA', '?'])

cars = df['name']

# Handle missing value
df['horsepower'] = df['horsepower'].fillna(df['horsepower'].median())

# Pandas to Numpy
x = df[['cylinders', 'displacement', 'horsepower', 'weight',
       'acceleration', 'year', 'origin']].values
y = df['mpg'].values # regression

# Build the neural network
model = Sequential()
model.add(Input(shape=(x.shape[1],)))# Hidden 1
# model.add(Dense(25, input_dim=x.shape[1], activation='relu')) # Hidden 1
model.add(Dense(10, activation='relu')) # Hidden 2
model.add(Dense(1)) # Output
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x,y,verbose=2,epochs=100)

# %%
pred = model.predict(x)
print(f"Shape: {pred.shape}")
print(pred[0:10])

# %%
# Measure RMSE error.  RMSE is common for regression.
score = np.sqrt(metrics.mean_squared_error(pred,y))
print(f"Final score (RMSE): {score}")

# %%
# Sample predictions
for i in range(10):
    print(f"{i+1}. Car name: {cars[i]}, MPG: {y[i]}, " 
          + f"predicted MPG: {pred[i]}")

# %%
import pandas as pd
import io
import requests
import numpy as np
from sklearn import metrics
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.callbacks import EarlyStopping

df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/iris.csv", 
    na_values=['NA', '?'])

# Convert to numpy - Classification
x = df[['sepal_l', 'sepal_w', 'petal_l', 'petal_w']].values
dummies = pd.get_dummies(df['species']) # Classification
species = dummies.columns
y = dummies.values


# Build neural network
model = Sequential()
model.add(Input(shape=(x.shape[1],)))# Hidden 1
model.add(Dense(25, activation='relu')) # Hidden 2
model.add(Dense(y.shape[1],activation='softmax')) # Output

model.compile(loss='categorical_crossentropy', optimizer='adam')
model.fit(x,y,verbose=2,epochs=100)
# Out:
# Epoch 1/100
# 5/5 - 1s - 137ms/step - loss: 1.6570
# Epoch 2/100
# 5/5 - 0s - 11ms/step - loss: 1.5512
# Epoch 3/100
# 5/5 - 0s - 11ms/step - loss: 1.4443
# Epoch 4/100
# 5/5 - 0s - 11ms/step - loss: 1.3543
# Epoch 5/100
# 5/5 - 0s - 11ms/step - loss: 1.2706
# Epoch 6/100
# 5/5 - 0s - 11ms/step - loss: 1.1938
# Epoch 7/100
# 5/5 - 0s - 11ms/step - loss: 1.1306
# Epoch 8/100
# 5/5 - 0s - 12ms/step - loss: 1.0726
# Epoch 9/100
# 5/5 - 0s - 13ms/step - loss: 1.0281
# Epoch 10/100
# 5/5 - 0s - 11ms/step - loss: 0.9895
# Epoch 11/100
# 5/5 - 0s - 12ms/step - loss: 0.9601
# Epoch 12/100
# 5/5 - 0s - 12ms/step - loss: 0.9333
# Epoch 13/100
# 5/5 - 0s - 14ms/step - loss: 0.9124
# Epoch 14/100
# 5/5 - 0s - 12ms/step - loss: 0.8919
# Epoch 15/100
# 5/5 - 0s - 12ms/step - loss: 0.8741
# Epoch 16/100
# 5/5 - 0s - 11ms/step - loss: 0.8575
# Epoch 17/100
# 5/5 - 0s - 11ms/step - loss: 0.8414
# Epoch 18/100
# 5/5 - 0s - 12ms/step - loss: 0.8259
# Epoch 19/100
# 5/5 - 0s - 11ms/step - loss: 0.8111
# Epoch 20/100
# 5/5 - 0s - 11ms/step - loss: 0.7967
# Epoch 21/100
# 5/5 - 0s - 12ms/step - loss: 0.7817
# Epoch 22/100
# 5/5 - 0s - 11ms/step - loss: 0.7680
# Epoch 23/100
# 5/5 - 0s - 11ms/step - loss: 0.7544
# Epoch 24/100
# 5/5 - 0s - 12ms/step - loss: 0.7410
# Epoch 25/100
# 5/5 - 0s - 15ms/step - loss: 0.7282
# Epoch 26/100
# 5/5 - 0s - 11ms/step - loss: 0.7166
# Epoch 27/100
# 5/5 - 0s - 11ms/step - loss: 0.7043
# Epoch 28/100
# 5/5 - 0s - 11ms/step - loss: 0.6933
# Epoch 29/100
# 5/5 - 0s - 14ms/step - loss: 0.6827
# Epoch 30/100
# 5/5 - 0s - 14ms/step - loss: 0.6732
# Epoch 31/100
# 5/5 - 0s - 11ms/step - loss: 0.6643
# Epoch 32/100
# 5/5 - 0s - 11ms/step - loss: 0.6551
# Epoch 33/100
# 5/5 - 0s - 11ms/step - loss: 0.6474
# Epoch 34/100
# 5/5 - 0s - 11ms/step - loss: 0.6392
# Epoch 35/100
# 5/5 - 0s - 11ms/step - loss: 0.6314
# Epoch 36/100
# 5/5 - 0s - 11ms/step - loss: 0.6248
# Epoch 37/100
# 5/5 - 0s - 11ms/step - loss: 0.6177
# Epoch 38/100
# 5/5 - 0s - 11ms/step - loss: 0.6103
# Epoch 39/100
# 5/5 - 0s - 11ms/step - loss: 0.6050
# Epoch 40/100
# 5/5 - 0s - 11ms/step - loss: 0.5978
# Epoch 41/100
# 5/5 - 0s - 12ms/step - loss: 0.5913
# Epoch 42/100
# 5/5 - 0s - 12ms/step - loss: 0.5848
# Epoch 43/100
# 5/5 - 0s - 11ms/step - loss: 0.5793
# Epoch 44/100
# 5/5 - 0s - 11ms/step - loss: 0.5731
# Epoch 45/100
# 5/5 - 0s - 11ms/step - loss: 0.5678
# Epoch 46/100
# 5/5 - 0s - 11ms/step - loss: 0.5623
# Epoch 47/100
# 5/5 - 0s - 11ms/step - loss: 0.5565
# Epoch 48/100
# 5/5 - 0s - 12ms/step - loss: 0.5511
# Epoch 49/100
# 5/5 - 0s - 11ms/step - loss: 0.5458
# Epoch 50/100
# 5/5 - 0s - 12ms/step - loss: 0.5406
# Epoch 51/100
# 5/5 - 0s - 12ms/step - loss: 0.5357
# Epoch 52/100
# 5/5 - 0s - 17ms/step - loss: 0.5307
# Epoch 53/100
# 5/5 - 0s - 11ms/step - loss: 0.5258
# Epoch 54/100
# 5/5 - 0s - 12ms/step - loss: 0.5214
# Epoch 55/100
# 5/5 - 0s - 11ms/step - loss: 0.5167
# Epoch 56/100
# 5/5 - 0s - 12ms/step - loss: 0.5123
# Epoch 57/100
# 5/5 - 0s - 11ms/step - loss: 0.5078
# Epoch 58/100
# 5/5 - 0s - 11ms/step - loss: 0.5038
# Epoch 59/100
# 5/5 - 0s - 11ms/step - loss: 0.4997
# Epoch 60/100
# 5/5 - 0s - 11ms/step - loss: 0.4950
# Epoch 61/100
# 5/5 - 0s - 12ms/step - loss: 0.4917
# Epoch 62/100
# 5/5 - 0s - 13ms/step - loss: 0.4864
# Epoch 63/100
# 5/5 - 0s - 11ms/step - loss: 0.4829
# Epoch 64/100
# 5/5 - 0s - 11ms/step - loss: 0.4792
# Epoch 65/100
# 5/5 - 0s - 11ms/step - loss: 0.4759
# Epoch 66/100
# 5/5 - 0s - 12ms/step - loss: 0.4713
# Epoch 67/100
# 5/5 - 0s - 12ms/step - loss: 0.4673
# Epoch 68/100
# 5/5 - 0s - 14ms/step - loss: 0.4637
# Epoch 69/100
# 5/5 - 0s - 12ms/step - loss: 0.4602
# Epoch 70/100
# 5/5 - 0s - 11ms/step - loss: 0.4566
# Epoch 71/100
# 5/5 - 0s - 11ms/step - loss: 0.4533
# Epoch 72/100
# 5/5 - 0s - 11ms/step - loss: 0.4509
# Epoch 73/100
# 5/5 - 0s - 11ms/step - loss: 0.4464
# Epoch 74/100
# 5/5 - 0s - 11ms/step - loss: 0.4432
# Epoch 75/100
# 5/5 - 0s - 10ms/step - loss: 0.4396
# Epoch 76/100
# 5/5 - 0s - 11ms/step - loss: 0.4365
# Epoch 77/100
# 5/5 - 0s - 11ms/step - loss: 0.4333
# Epoch 78/100
# 5/5 - 0s - 11ms/step - loss: 0.4301
# Epoch 79/100
# 5/5 - 0s - 11ms/step - loss: 0.4268
# Epoch 80/100
# 5/5 - 0s - 11ms/step - loss: 0.4242
# Epoch 81/100
# 5/5 - 0s - 11ms/step - loss: 0.4206
# Epoch 82/100
# 5/5 - 0s - 11ms/step - loss: 0.4176
# Epoch 83/100
# 5/5 - 0s - 13ms/step - loss: 0.4150
# Epoch 84/100
# 5/5 - 0s - 10ms/step - loss: 0.4117
# Epoch 85/100
# 5/5 - 0s - 11ms/step - loss: 0.4084
# Epoch 86/100
# 5/5 - 0s - 11ms/step - loss: 0.4059
# Epoch 87/100
# 5/5 - 0s - 11ms/step - loss: 0.4034
# Epoch 88/100
# 5/5 - 0s - 11ms/step - loss: 0.4001
# Epoch 89/100
# 5/5 - 0s - 11ms/step - loss: 0.3971
# Epoch 90/100
# 5/5 - 0s - 11ms/step - loss: 0.3941
# Epoch 91/100
# 5/5 - 0s - 11ms/step - loss: 0.3914
# Epoch 92/100
# 5/5 - 0s - 11ms/step - loss: 0.3888
# Epoch 93/100
# 5/5 - 0s - 15ms/step - loss: 0.3859
# Epoch 94/100
# 5/5 - 0s - 11ms/step - loss: 0.3831
# Epoch 95/100
# 5/5 - 0s - 11ms/step - loss: 0.3807
# Epoch 96/100
# 5/5 - 0s - 12ms/step - loss: 0.3781
# Epoch 97/100
# 5/5 - 0s - 11ms/step - loss: 0.3751
# Epoch 98/100
# 5/5 - 0s - 11ms/step - loss: 0.3726
# Epoch 99/100
# 5/5 - 0s - 11ms/step - loss: 0.3700
# Epoch 100/100
# 5/5 - 0s - 11ms/step - loss: 0.3680
